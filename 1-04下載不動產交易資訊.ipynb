# %% [markdown]
# # 下載不動產交易資訊
#
# 相關連結：
#
# * [內政資料開放平台](https://data.moi.gov.tw/MoiOD/Data/DataDetail.aspx?oid=B0932B74-D86E-4128-90DA-A207C29F8436)

# %%
# !rm *.csv

# %%
# !wget https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=19059799-9436-4D7D-8C5E-90F1A9CE82DA -O real.zip -o /dev/null

# %%
# !unzip real.zip > /dev/null

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/a_lvr_land_a.csv')

# %%
df.head(2)
# Out:
#   鄉鎮市區       交易標的  ...                       備註                   編號
# 1  文山區  房地(土地+建物)  ...  依仲介公司提供之資料登錄，含增建或未登記建物。  RPPNMLLKKHOFFAA96CA
# 2  文山區  房地(土地+建物)  ...                      NaN  RPRNMLMKKHOFFAA27CA
#
# [2 rows x 28 columns]

# %%
df.drop(0, inplace=True)

# %%
df.head(2)
# Out:
#   鄉鎮市區          交易標的  ...                       備註                   編號
# 1  文山區     房地(土地+建物)  ...  依仲介公司提供之資料登錄，含增建或未登記建物。  RPPNMLLKKHOFFAA96CA
# 2  文山區     房地(土地+建物)  ...                      NaN  RPRNMLMKKHOFFAA27CA
# 3  文山區  房地(土地+建物)+車位  ...              含增建或未登記建物。;  RPSNMLMKKHOFFAA37CA
# 4  文山區     房地(土地+建物)  ...              含增建或未登記建物。;  RPTNMLMKKHOFFAA47CA
# 5  文山區     房地(土地+建物)  ...                      NaN  RPXNMLMKKHOFFAA87CA
#
# [5 rows x 28 columns]

# %%
df['總價元']=df['總價元'].astype('int')

# %%
df[df['總價元']<1000000]
# Out:
#    鄉鎮市區       交易標的  ...                      備註                   編號
# 22  內湖區         土地  ...          包含公共設施保留地之交易。;  RPTPMLKLKHOFFCA77CA
# 23  內湖區         土地  ...          包含公共設施保留地之交易。;  RPUPMLKLKHOFFCA87CA
# 24  內湖區         土地  ...          包含公共設施保留地之交易。;  RPWPMLKLKHOFFCA08CA
# 25  內湖區         土地  ...          包含公共設施保留地之交易。;  RPXPMLKLKHOFFCA18CA
# 26  內湖區         土地  ...          包含公共設施保留地之交易。;  RPPQMLKLKHOFFCA47CA
# 27  內湖區         土地  ...          包含公共設施保留地之交易。;  RPQQMLKLKHOFFCA57CA
# 28  內湖區         土地  ...          包含公共設施保留地之交易。;  RPRQMLKLKHOFFCA67CA
# 29  內湖區         土地  ...          包含公共設施保留地之交易。;  RPSQMLKLKHOFFCA77CA
# 30  內湖區         土地  ...          包含公共設施保留地之交易。;  RPTQMLKLKHOFFCA87CA
# 31  內湖區         土地  ...          包含公共設施保留地之交易。;  RPUQMLKLKHOFFCA97CA
# 32  內湖區         土地  ...          包含公共設施保留地之交易。;  RPWQMLKLKHOFFCA18CA
# 33  內湖區         土地  ...          包含公共設施保留地之交易。;  RPXQMLKLKHOFFCA28CA
# 34  內湖區         土地  ...          包含公共設施保留地之交易。;  RPORMLKLKHOFFCA47CA
# ...
